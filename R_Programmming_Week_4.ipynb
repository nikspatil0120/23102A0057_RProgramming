# %% [markdown]
# <a href="https://colab.research.google.com/github/nikspatil0120/23102A0057_RProgramming/blob/main/R_Programmming_Week_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nikhil Patil
#
# BE CMPN A 23102A0057
#
# R Programmming Week 4

# %% [markdown]
# <h2>Changing the row and column Names

# %%
x = matrix(nrow=4, ncol=3, data=c(1:12))
x
# Out:
#      [,1] [,2] [,3]
# [1,] 1    5     9
# [2,] 2    6    10
# [3,] 3    7    11
# [4,] 4    8    12

# %% [markdown]
# Row name

# %%
rownames(x)=c("r1","r2","r3","r4")
x
# Out:
#    [,1] [,2] [,3]
# r1 1    5     9
# r2 2    6    10
# r3 3    7    11
# r4 4    8    12

# %% [markdown]
# Column name

# %%
colnames(x)=c("c1","c2","c3")
x
# Out:
#    c1 c2 c3
# r1 1  5   9
# r2 2  6  10
# r3 3  7  11
# r4 4  8  12

# %% [markdown]
# Assigning Specific Number to all the elements

# %%
x=matrix(nrow=4,ncol=2,data=2)
x
# Out:
#      [,1] [,2]
# [1,] 2    2
# [2,] 2    2
# [3,] 2    2
# [4,] 2    2

# %% [markdown]
# Diagonal Matrix with 1

# %%
d=diag(1,nrow=3 , ncol=3)
d
# Out:
#      [,1] [,2] [,3]
# [1,] 1    0    0
# [2,] 0    1    0
# [3,] 0    0    1

# %% [markdown]
# Daiagonal matrix with 5

# %%
d=diag(5,nrow=3,ncol=3)
d
# Out:
#      [,1] [,2] [,3]
# [1,] 5    0    0
# [2,] 0    5    0
# [3,] 0    0    5

# %% [markdown]
# <H2>Transponse of Matrix

# %%
x=matrix(nrow=4,ncol=2,data=1:8,byrow=T)
x
# Out:
#      [,1] [,2]
# [1,] 1    2
# [2,] 3    4
# [3,] 5    6
# [4,] 7    8

# %%
xt=t(x)
xt
# Out:
#      [,1] [,2] [,3] [,4]
# [1,] 1    3    5    7
# [2,] 2    4    6    8

# %% [markdown]
# <H2>Rowwise and Columnwise sums

# %%
x=matrix(nrow=4,ncol=2,data=c(1,2,3,4,5,6,7,8))
x
# Out:
#      [,1] [,2]
# [1,] 1    5
# [2,] 2    6
# [3,] 3    7
# [4,] 4    8

# %%
rowSums(x)
colSums(x)
# Out:
# [1]  6  8 10 12
# [1] 10 26

# %% [markdown]
# <h2>Rowwise and Columnwise Mean

# %%
x=matrix(nrow=4,ncol=2,data=c(1,2,3,4,5,6,7,8))
x
# Out:
#      [,1] [,2]
# [1,] 1    5
# [2,] 2    6
# [3,] 3    7
# [4,] 4    8

# %%
rowMeans(x)
# Out:
# [1] 3 4 5 6

# %%
colMeans(x)
# Out:
# [1] 2.5 6.5

# %% [markdown]
# <h2>Access to rows,columns or submatrices

# %%
x=matrix(nrow=5,ncol=3,byrow=T,data=1:15)
x
# Out:
#      [,1] [,2] [,3]
# [1,]  1    2    3
# [2,]  4    5    6
# [3,]  7    8    9
# [4,] 10   11   12
# [5,] 13   14   15

# %% [markdown]
# row

# %%
x[3,]
# Out:
# [1] 7 8 9

# %% [markdown]
# column

# %%
x[,2]
# Out:
# [1]  2  5  8 11 14

# %% [markdown]
# submatrix

# %%
x[4:5,2:3]
# Out:
#      [,1] [,2]
# [1,] 11   12
# [2,] 14   15

# %% [markdown]
# boundary element matrix

# %%
x[c(1,4),c(1,3)]
# Out:
#      [,1] [,2]
# [1,]  1    3
# [2,] 10   12

# %% [markdown]
# <h2>Addition with Constant

# %%
x=matrix(nrow=4,ncol=2,byrow=T,data=1:8)
x
# Out:
#      [,1] [,2]
# [1,] 1    2
# [2,] 3    4
# [3,] 5    6
# [4,] 7    8

# %%
x+5
# Out:
#      [,1] [,2]
# [1,]  6    7
# [2,]  8    9
# [3,] 10   11
# [4,] 12   13

# %% [markdown]
# <h2>Subtraction with Constant

# %%
x=matrix(nrow=4,ncol=2,byrow=T,data=1:8)
x
# Out:
#      [,1] [,2]
# [1,] 1    2
# [2,] 3    4
# [3,] 5    6
# [4,] 7    8

# %%
x-5
# Out:
#      [,1] [,2]
# [1,] -4   -3
# [2,] -2   -1
# [3,]  0    1
# [4,]  2    3

# %% [markdown]
# <h2>Multiplication with Constant

# %%
x=matrix(nrow=4,ncol=2,byrow=T,data=1:8)
x

# %%
5*x
# Out:
#      [,1] [,2]
# [1,]  5   10
# [2,] 15   20
# [3,] 25   30
# [4,] 35   40

# %% [markdown]
# <h2>Division with Constant

# %%
x=matrix(nrow=4,ncol=2,byrow=T,data=1:8)
x
# Out:
#      [,1] [,2]
# [1,] 1    2
# [2,] 3    4
# [3,] 5    6
# [4,] 7    8

# %%
x/2
# Out:
#      [,1] [,2]
# [1,] 0.5  1
# [2,] 1.5  2
# [3,] 2.5  3
# [4,] 3.5  4

# %% [markdown]
# <h2>Matrix addition

# %%
x=matrix(nrow=4,ncol=2,byrow=T,data=1:8)
y=matrix(nrow=4,ncol=2,byrow=T,data=11:18)

# %%
x+y
# Out:
#      [,1] [,2]
# [1,] 12   14
# [2,] 16   18
# [3,] 20   22
# [4,] 24   26

# %% [markdown]
# <h2>Matrix subtraction

# %%
x=matrix(nrow=4,ncol=2,byrow=T,data=1:8)
y=matrix(nrow=4,ncol=2,byrow=T,data=11:18)

# %%
x-y
# Out:
#      [,1] [,2]
# [1,] -10  -10
# [2,] -10  -10
# [3,] -10  -10
# [4,] -10  -10

# %% [markdown]
# <h2>Various arithmetic operations

# %%
x=matrix(nrow=4,ncol=2,byrow=T,data=1:8)
x
# Out:
#      [,1] [,2]
# [1,] 1    2
# [2,] 3    4
# [3,] 5    6
# [4,] 7    8

# %%
x+4*x
# Out:
#      [,1] [,2]
# [1,]  5   10
# [2,] 15   20
# [3,] 25   30
# [4,] 35   40

# %%
4*x-x
# Out:
#      [,1] [,2]
# [1,]  3    6
# [2,]  9   12
# [3,] 15   18
# [4,] 21   24

# %% [markdown]
# <h2>Matrix mulitplication

# %%
x=matrix(nrow=4,ncol=2,byrow=T,data=1:8)
y=matrix(nrow=2,ncol=4,byrow=T,data=11:18)

# %%
x%*%y
# Out:
#      [,1] [,2] [,3] [,4]
# [1,]  41   44   47   50
# [2,]  93  100  107  114
# [3,] 145  156  167  178
# [4,] 197  212  227  242

# %%
y%*%x
# Out:
#      [,1] [,2]
# [1,] 210  260
# [2,] 274  340

# %%
x=matrix(nrow=4,ncol=2,byrow=T,data=1:8)
x
# Out:
#      [,1] [,2]
# [1,] 1    2
# [2,] 3    4
# [3,] 5    6
# [4,] 7    8

# %%
t(x)
# Out:
#      [,1] [,2] [,3] [,4]
# [1,] 1    3    5    7
# [2,] 2    4    6    8

# %%
t(x)%*%x
# Out:
#      [,1] [,2]
# [1,]  84  100
# [2,] 100  120

# %%
x%*%t(x)
# Out:
#      [,1] [,2] [,3] [,4]
# [1,]  5   11   17    23
# [2,] 11   25   39    53
# [3,] 17   39   61    83
# [4,] 23   53   83   113

# %%
x=matrix(nrow=4,ncol=2,byrow=T,data=1:8)

# %% [markdown]
# crossproduct of x , xx' using function

# %%
crossprod(x)
# Out:
#      [,1] [,2]
# [1,]  84  100
# [2,] 100  120

# %% [markdown]
# <h2>Concatenation of Matrix

# %%
x=matrix(nrow=4,ncol=2,byrow=T,data=1:8)
y=matrix(nrow=4,ncol=2,byrow=T,data=11:18)

# %% [markdown]
# Row

# %%
rbind(x,y)
# Out:
#      [,1] [,2]
# [1,]  1    2
# [2,]  3    4
# [3,]  5    6
# [4,]  7    8
# [5,] 11   12
# [6,] 13   14
# [7,] 15   16
# [8,] 17   18

# %% [markdown]
# Column

# %%
cbind(x,y)
# Out:
#      [,1] [,2] [,3] [,4]
# [1,] 1    2    11   12
# [2,] 3    4    13   14
# [3,] 5    6    15   16
# [4,] 7    8    17   18

# %%
y=matrix(nrow=2,ncol=2,byrow=T,data=c(84,100,100,120))
y
# Out:
#      [,1] [,2]
# [1,]  84  100
# [2,] 100  120

# %% [markdown]
# Calculate Inverse

# %%
solve(y)
# Out:
#      [,1]  [,2]
# [1,]  1.50 -1.25
# [2,] -1.25  1.05

# %% [markdown]
# Eigen Values and Eigen Vectors

# %%
eigen(y)
# Out:
# eigen() decomposition
# $values
# [1] 203.6070864   0.3929136
#
# $vectors
#           [,1]       [,2]
# [1,] 0.6414230 -0.7671874
# [2,] 0.7671874  0.6414230

# %% [markdown]
# <h2>Logical Operators

# %% [markdown]
# Logical OR

# %%
x=8
x<10 || x<2
# Out:
# [1] TRUE

# %% [markdown]
# Element wise Logical OR

# %%
x=c(8,18)
(x<10) | (x<2)
# Out:
# [1]  TRUE FALSE

# %% [markdown]
# Logical AND

# %%
x=5
x<10 && x>2
# Out:
# [1] TRUE

# %% [markdown]
# Element Wise Logical AND

# %%
x=c(8,18)
x<10 & x>2
# Out:
# [1]  TRUE FALSE

# %%
x=1:6
x>2 & x<5
x[x>2 & x<5]
# Out:
# [1] FALSE FALSE  TRUE  TRUE FALSE FALSE
# [1] 3 4

# %%
x=5
Logical1=x>2
Logical1
# Out:
# [1] TRUE

# %% [markdown]
# is.logical check whether the expression is logical operation or not

# %%
is.logical(Logical1)
# Out:
# [1] TRUE

# %%
Logical2=x!=5
Logical2
# Out:
# [1] FALSE

# %%
is.logical(Logical2)
# Out:
# [1] TRUE

# %%
isTRUE(8<6)
isTRUE(8>6)
isFALSE(8<6)
isFALSE(8>6)
# Out:
# [1] FALSE
# [1] TRUE
# [1] TRUE
# [1] FALSE
